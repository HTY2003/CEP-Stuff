# %%
import pandas as pd
import numpy as np

data= pd.read_csv('2015TreeData.csv')
data_length= len(data)
print("length =", len(data))
# Out:
# length = 468341

# %%
data.dtypes
# Out:
# FID             int64
# tree_id         int64
# block_id        int64
# created_at     object
# tree_dbh        int64
# stump_diam      int64
# curb_loc       object
# status         object
# health         object
# spc_latin      object
# spc_common     object
# steward        object
# guards         object
# sidewalk       object
# user_type      object
# root_stone     object
# root_grate     object
# root_other     object
# trunk_wire     object
# trnk_light     object
# trnk_other     object
# brch_light     object
# brch_shoe      object
# brch_other     object
# address        object
# zipcode         int64
# zip_city       object
# cb_num          int64
# borocode        int64
# boroname       object
# cncldist        int64
# st_assem        int64
# st_senate       int64
# nta            object
# nta_name       object
# boro_ct         int64
# state          object
# latitude      float64
# longitude     float64
# x_sp          float64
# y_sp          float64
# dtype: object

# %%
print(data.ix[246089,"tree_id"])#prints are for checking

data.ix[246089,"spc_common"]
# Out:
# 296449
# 'Norway Maple'

# %%
print(data.at[246160,"tree_id"])

data.at[246160,"spc_common"]
# Out:
# 296530
# 'Cucumber Magnolia'

# %%
print(data.iat[246160,0])

data.iat[246160,10]
# Out:
# 246153
# 'Cucumber Magnolia'

# %%
print(data.loc[108,"FID"])

data.loc[108,"spc_common"]
# Out:
# 108
# 'Common Hackberry'

# %%
print(data.iloc[358913,1])

data.iloc[358913,10]
# Out:
# 431232
# 'Northern Red Oak'

# %%
dead_or_stump = data[(data.status == "Stump") | (data.status == "Dead")]
dead_or_stump_number = len(dead_or_stump)
print(dead_or_stump_number)
# Out:
# 21845

# %%
data = data[(data.status == "Alive")]

# %%
data
# Out:
#            FID  tree_id  block_id  created_at  tree_dbh  stump_diam curb_loc  \
# 0            0   101233    216486  07/29/2015         4           0   OnCurb
# 1            1   101234    216486  07/29/2015         4           0   OnCurb
# 2            2   101235    216486  07/29/2015         4           0   OnCurb
# 3            3   101400    216291  07/29/2015        15           0   OnCurb
# 4            4   101401    216291  07/29/2015        18           0   OnCurb
# 5            5   101402    216291  07/29/2015        17           0   OnCurb
# 6            6   101403    216291  07/29/2015        14           0   OnCurb
# 7            7   101404    216291  07/29/2015        14           0   OnCurb
# 8            8   101405    216291  07/29/2015        15           0   OnCurb
# 9            9   101406    216291  07/29/2015        18           0   OnCurb
# 10          10   101407    216291  07/29/2015        16           0   OnCurb
# ...

# %%
del data['stump_diam']

# %%
print("Volunteer:", len(data[data.user_type == "Volunteer"]))
print("TreesCount Staff:", len(data[data.user_type == "TreesCount Staff"]))
print("NYC Parks Staff:", len(data[data.user_type == "NYC Parks Staff"]))
# Out:
# Volunteer: 154133
# TreesCount Staff: 187724
# NYC Parks Staff: 97466

# %%
data5=data[(data.boroname=="Brooklyn")]
maxd=data5.tree_dbh.max()
print( "Largest tree diameter in brooklyn",maxd)
# Out:
# 318

# %%
print("Trees which have a diameter of greater than or equal to 25:",len(data[data.tree_dbh >= 25]))
# Out:
# 31958

# %%
data2=data[(data.boroname=="Manhattan")&(data.spc_common=="American Linden")]
bestofdata2=data2["tree_dbh"].max()
data2=data[(data.boroname=="Manhattan")&(data.spc_common=="American Linden")&(data.tree_dbh==bestofdata2)]
print("Latitude:",data2.at[440929,"latitude"]," Longitude:",data2.at[440929,"longitude"])
# Out:
# Latitude: 40.79949939  Longitude: -73.97314044

# %%
print("How many trees have a diameter of 16 and a health rating of Fair in the neighborhood of Corona:",len(data[(data.tree_dbh==16)&(data.health=="Fair")&(data.nta_name=="Corona")]))
# Out:
# how many trees have a diameter of 16 and a health rating of Fair in the neighborhood of Corona: 15

# %%
# Out:
# c:\python35-32\lib\site-packages\pandas\core\generic.py:3110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
data.ix[12390,"tree_dbh"]=10
data.ix[12390,"health"]='Fair'
data.ix[12390,"tree_id"]="None"
